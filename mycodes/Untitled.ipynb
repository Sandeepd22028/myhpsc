# %%
import numpy as np
import matplotlib.pyplot as plt
import math
tol=1.0e-14
def my_exp(k,n=100,debug=False):
    y=0
    for i in range(0,n):
        temp=y
        y=y+k**i/np.math.factorial(i)
        if debug:
            if(abs(y-temp)<tol):
                print(f"series is converged at i={i}")
            break
    return y

# %%
x=2
my_exp(x,100,True)
# Out:
# 1.0

# %%
x=np.linspace(0,100,1000)
y=my_exp(x)
z=np.exp(x)
plt.plot(x,y,'-r',label="my_exp")
plt.plot(x,z,'-b',label="numpy_exp")
plt.legend()
plt.show()

# %%
def k(x):
    y=np.log(x)
    return y
def l(v):
    s=np.exp(x)
    return s
# %timeit k(2)
# %timeit l(2)
# Out:
# 1.57 µs ± 71.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 11.6 µs ± 262 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
